# %% [markdown]
# # Data Wrangling

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('Global_Music_Streaming_Listener_Preferences.csv',encoding ="ISO-8859-1")
# Out:
#      User_ID  Age      Country Streaming Platform Top Genre  \
# 0      U1000   34        Japan              Tidal    Reggae
# 1      U1001   24      Germany             Deezer   Country
# 2      U1002   49      Germany             Deezer       Pop
# 3      U1003   55    Australia            YouTube    Reggae
# 4      U1004   13      Germany       Amazon Music    Reggae
# ...      ...  ...          ...                ...       ...
# 4995   U5995   60           UK             Deezer   Country
# 4996   U5996   38    Australia             Deezer   Hip-Hop
# 4997   U5997   27       Brazil       Amazon Music     Metal
# 4998   U5998   58       Canada       Amazon Music       EDM
# 4999   U5999   30  South Korea            YouTube      Rock
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 0                          295                    138              Adele
# 1                           86                    388         Ed Sheeran
# 2                          363                    368        Post Malone
# 3                          348                    349           Dua Lipa
# 4                           30                    328              Adele
# ...                        ...                    ...                ...
# 4995                       348                     81        Post Malone
# 4996                       225                    218                BTS
# 4997                       568                    277       Taylor Swift
# 4998                       523                    492          Bad Bunny
# 4999                       451                    145              Adele
#
#      Subscription Type Listening Time (Morning/Afternoon/Night)  \
# 0                 Free                                Afternoon
# 1              Premium                                    Night
# 2              Premium                                Afternoon
# 3              Premium                                  Morning
# 4                 Free                                    Night
# ...                ...                                      ...
# 4995           Premium                                  Morning
# 4996           Premium                                    Night
# 4997           Premium                                    Night
# 4998           Premium                                    Night
# 4999           Premium                                    Night
#
#       Discover Weekly Engagement (%)  Repeat Song Rate (%)
# 0                              47.42                 16.74
# 1                              12.06                 69.25
# 2                              47.19                 67.38
# 3                              31.27                 76.51
# 4                              30.68                 43.41
# ...                              ...                   ...
# 4995                           49.23                 22.36
# 4996                           17.08                 58.23
# 4997                           69.39                 51.71
# 4998                           43.44                 24.53
# 4999                           15.45                 79.46
#
# [5000 rows x 12 columns]

# %%
project=pd.read_csv('Global_Music_Streaming_Listener_Preferences.csv',encoding ="ISO-8859-1")

# %%
project
# Out:
#      User_ID  Age      Country Streaming Platform Top Genre  \
# 0      U1000   34        Japan              Tidal    Reggae
# 1      U1001   24      Germany             Deezer   Country
# 2      U1002   49      Germany             Deezer       Pop
# 3      U1003   55    Australia            YouTube    Reggae
# 4      U1004   13      Germany       Amazon Music    Reggae
# ...      ...  ...          ...                ...       ...
# 4995   U5995   60           UK             Deezer   Country
# 4996   U5996   38    Australia             Deezer   Hip-Hop
# 4997   U5997   27       Brazil       Amazon Music     Metal
# 4998   U5998   58       Canada       Amazon Music       EDM
# 4999   U5999   30  South Korea            YouTube      Rock
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 0                          295                    138              Adele
# 1                           86                    388         Ed Sheeran
# 2                          363                    368        Post Malone
# 3                          348                    349           Dua Lipa
# 4                           30                    328              Adele
# ...                        ...                    ...                ...
# 4995                       348                     81        Post Malone
# 4996                       225                    218                BTS
# 4997                       568                    277       Taylor Swift
# 4998                       523                    492          Bad Bunny
# 4999                       451                    145              Adele
#
#      Subscription Type Listening Time (Morning/Afternoon/Night)  \
# 0                 Free                                Afternoon
# 1              Premium                                    Night
# 2              Premium                                Afternoon
# 3              Premium                                  Morning
# 4                 Free                                    Night
# ...                ...                                      ...
# 4995           Premium                                  Morning
# 4996           Premium                                    Night
# 4997           Premium                                    Night
# 4998           Premium                                    Night
# 4999           Premium                                    Night
#
#       Discover Weekly Engagement (%)  Repeat Song Rate (%)
# 0                              47.42                 16.74
# 1                              12.06                 69.25
# 2                              47.19                 67.38
# 3                              31.27                 76.51
# 4                              30.68                 43.41
# ...                              ...                   ...
# 4995                           49.23                 22.36
# 4996                           17.08                 58.23
# 4997                           69.39                 51.71
# 4998                           43.44                 24.53
# 4999                           15.45                 79.46
#
# [5000 rows x 12 columns]

# %%
project.isnull().sum()
# Out:
# User_ID                                     0
# Age                                         0
# Country                                     0
# Streaming Platform                          0
# Top Genre                                   0
# Minutes Streamed Per Day                    0
# Number of Songs Liked                       0
# Most Played Artist                          0
# Subscription Type                           0
# Listening Time (Morning/Afternoon/Night)    0
# Discover Weekly Engagement (%)              0
# Repeat Song Rate (%)                        0
# dtype: int64

# %%
project.duplicated().sum()
# Out:
# 0

# %%
project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   User_ID                                   5000 non-null   object
#  1   Age                                       5000 non-null   int64
#  2   Country                                   5000 non-null   object
#  3   Streaming Platform                        5000 non-null   object
#  4   Top Genre                                 5000 non-null   object
#  5   Minutes Streamed Per Day                  5000 non-null   int64
#  6   Number of Songs Liked                     5000 non-null   int64
#  7   Most Played Artist                        5000 non-null   object
#  8   Subscription Type                         5000 non-null   object
#  9   Listening Time (Morning/Afternoon/Night)  5000 non-null   object
#  10  Discover Weekly Engagement (%)            5000 non-null   float64
#  11  Repeat Song Rate (%)                      5000 non-null   float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 468.9+ KB

# %% [markdown]
# # Data Analysis

# %%
#To find the mean of "Minutes Streamed Per Day" by Country wise 
project.groupby('Country')['Minutes Streamed Per Day'].mean()
# Out:
# Country
# Australia      314.878327
# Brazil         293.712598
# Canada         307.692308
# France         318.649087
# Germany        321.961783
# India          305.512245
# Japan          306.578411
# South Korea    316.238372
# UK             309.767442
# USA            297.439834
# Name: Minutes Streamed Per Day, dtype: float64

# %%
#Create new Column and Convert the minutes into hours and Store this data into the new column "Daily Hours Streamed"
project['Daily Hours Streamed']=project['Minutes Streamed Per Day']/60

# %%
project
# Out:
#      User_ID  Age      Country Streaming Platform Top Genre  \
# 0      U1000   34        Japan              Tidal    Reggae
# 1      U1001   24      Germany             Deezer   Country
# 2      U1002   49      Germany             Deezer       Pop
# 3      U1003   55    Australia            YouTube    Reggae
# 4      U1004   13      Germany       Amazon Music    Reggae
# ...      ...  ...          ...                ...       ...
# 4995   U5995   60           UK             Deezer   Country
# 4996   U5996   38    Australia             Deezer   Hip-Hop
# 4997   U5997   27       Brazil       Amazon Music     Metal
# 4998   U5998   58       Canada       Amazon Music       EDM
# 4999   U5999   30  South Korea            YouTube      Rock
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 0                          295                    138              Adele
# 1                           86                    388         Ed Sheeran
# 2                          363                    368        Post Malone
# 3                          348                    349           Dua Lipa
# 4                           30                    328              Adele
# ...                        ...                    ...                ...
# 4995                       348                     81        Post Malone
# 4996                       225                    218                BTS
# 4997                       568                    277       Taylor Swift
# 4998                       523                    492          Bad Bunny
# 4999                       451                    145              Adele
#
#      Subscription Type Listening Time (Morning/Afternoon/Night)  \
# 0                 Free                                Afternoon
# 1              Premium                                    Night
# 2              Premium                                Afternoon
# 3              Premium                                  Morning
# 4                 Free                                    Night
# ...                ...                                      ...
# 4995           Premium                                  Morning
# 4996           Premium                                    Night
# 4997           Premium                                    Night
# 4998           Premium                                    Night
# 4999           Premium                                    Night
#
#       Discover Weekly Engagement (%)  Repeat Song Rate (%)  \
# 0                              47.42                 16.74
# 1                              12.06                 69.25
# 2                              47.19                 67.38
# 3                              31.27                 76.51
# 4                              30.68                 43.41
# ...                              ...                   ...
# 4995                           49.23                 22.36
# 4996                           17.08                 58.23
# 4997                           69.39                 51.71
# 4998                           43.44                 24.53
# 4999                           15.45                 79.46
#
#       Daily Hours Streamed
# 0                 4.916667
# 1                 1.433333
# 2                 6.050000
# 3                 5.800000
# 4                 0.500000
# ...                    ...
# 4995              5.800000
# 4996              3.750000
# 4997              9.466667
# 4998              8.716667
# 4999              7.516667
#
# [5000 rows x 13 columns]

# %%
#Finding the top 5 combinations of Genre and Most played artist  
project.groupby(['Top Genre','Most Played Artist']).size().sort_values(ascending=False).head().reset_index()
# Out:
#    Top Genre Most Played Artist   0
# 0  Classical              Adele  64
# 1     Reggae       Taylor Swift  64
# 2     Reggae              Adele  62
# 3     Reggae         Ed Sheeran  60
# 4      Metal              Adele  60

# %%
#Count the number of users of each genre Country wise
project.groupby('Country')['Top Genre'].value_counts()
# Out:
# Country    Top Genre
# Australia  Pop          61
#            Jazz         60
#            Hip-Hop      55
#            Reggae       55
#            Rock         55
#                         ..
# USA        Classical    48
#            Country      46
#            Pop          43
#            R&B          38
#            Hip-Hop      34
# Name: count, Length: 100, dtype: int64

# %%
#Create a function to categorize the ages to Teen, Young Adult, Adult and seniors then make a new column "Age_Group" 
#and apply function in the age column 
def age_category(age):
    if age < 20:
        return 'Teen'
    elif age < 30:
        return 'Young Adult'
    elif age < 60:
        return 'Adult'
    else:
        return 'Senior'

project['Age_Group'] = project['Age'].apply(age_category)

# %%
project
# Out:
#      User_ID  Age      Country Streaming Platform Top Genre  \
# 0      U1000   34        Japan              Tidal    Reggae
# 1      U1001   24      Germany             Deezer   Country
# 2      U1002   49      Germany             Deezer       Pop
# 3      U1003   55    Australia            YouTube    Reggae
# 4      U1004   13      Germany       Amazon Music    Reggae
# ...      ...  ...          ...                ...       ...
# 4995   U5995   60           UK             Deezer   Country
# 4996   U5996   38    Australia             Deezer   Hip-Hop
# 4997   U5997   27       Brazil       Amazon Music     Metal
# 4998   U5998   58       Canada       Amazon Music       EDM
# 4999   U5999   30  South Korea            YouTube      Rock
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 0                          295                    138              Adele
# 1                           86                    388         Ed Sheeran
# 2                          363                    368        Post Malone
# 3                          348                    349           Dua Lipa
# 4                           30                    328              Adele
# ...                        ...                    ...                ...
# 4995                       348                     81        Post Malone
# 4996                       225                    218                BTS
# 4997                       568                    277       Taylor Swift
# 4998                       523                    492          Bad Bunny
# 4999                       451                    145              Adele
#
#      Subscription Type Listening Time (Morning/Afternoon/Night)  \
# 0                 Free                                Afternoon
# 1              Premium                                    Night
# 2              Premium                                Afternoon
# 3              Premium                                  Morning
# 4                 Free                                    Night
# ...                ...                                      ...
# 4995           Premium                                  Morning
# 4996           Premium                                    Night
# 4997           Premium                                    Night
# 4998           Premium                                    Night
# 4999           Premium                                    Night
#
#       Discover Weekly Engagement (%)  Repeat Song Rate (%)  \
# 0                              47.42                 16.74
# 1                              12.06                 69.25
# 2                              47.19                 67.38
# 3                              31.27                 76.51
# 4                              30.68                 43.41
# ...                              ...                   ...
# 4995                           49.23                 22.36
# 4996                           17.08                 58.23
# 4997                           69.39                 51.71
# 4998                           43.44                 24.53
# 4999                           15.45                 79.46
#
#       Daily Hours Streamed    Age_Group
# 0                 4.916667        Adult
# 1                 1.433333  Young Adult
# 2                 6.050000        Adult
# 3                 5.800000        Adult
# 4                 0.500000         Teen
# ...                    ...          ...
# 4995              5.800000       Senior
# 4996              3.750000        Adult
# 4997              9.466667  Young Adult
# 4998              8.716667        Adult
# 4999              7.516667        Adult
#
# [5000 rows x 14 columns]

# %%
#Find the sum of liked songs among each age group 
project.groupby('Age_Group')['Number of Songs Liked'].sum()
# Out:
# Age_Group
# Adult          788690
# Senior          28641
# Teen           180733
# Young Adult    269522
# Name: Number of Songs Liked, dtype: int64

# %%
#Find the sum of daily hours streamed among each age group and each Genre
project.groupby(['Age_Group','Top Genre'])['Daily Hours Streamed'].sum().reset_index()
# Out:
#       Age_Group  Top Genre  Daily Hours Streamed
# 0         Adult  Classical           1623.083333
# 1         Adult    Country           1470.550000
# 2         Adult        EDM           1598.816667
# 3         Adult    Hip-Hop           1640.283333
# 4         Adult       Jazz           1660.533333
# 5         Adult      Metal           1523.650000
# 6         Adult        Pop           1520.900000
# 7         Adult        R&B           1725.200000
# 8         Adult     Reggae           1647.666667
# 9         Adult       Rock           1825.033333
# 10       Senior  Classical             40.333333
# 11       Senior    Country             28.916667
# 12       Senior        EDM             80.283333
# 13       Senior    Hip-Hop             64.533333
# 14       Senior       Jazz             65.783333
# 15       Senior      Metal             48.000000
# 16       Senior        Pop             44.733333
# 17       Senior        R&B             79.850000
# 18       Senior     Reggae             87.216667
# 19       Senior       Rock             42.733333
# 20         Teen  Classical            401.383333
# 21         Teen    Country            361.133333
# 22         Teen        EDM            364.466667
# 23         Teen    Hip-Hop            368.700000
# 24         Teen       Jazz            403.516667
# 25         Teen      Metal            388.650000
# 26         Teen        Pop            293.100000
# 27         Teen        R&B            293.150000
# 28         Teen     Reggae            410.550000
# 29         Teen       Rock            344.300000
# 30  Young Adult  Classical            418.050000
# 31  Young Adult    Country            508.966667
# 32  Young Adult        EDM            687.200000
# 33  Young Adult    Hip-Hop            443.916667
# 34  Young Adult       Jazz            609.200000
# 35  Young Adult      Metal            510.233333
# 36  Young Adult        Pop            491.083333
# 37  Young Adult        R&B            500.950000
# 38  Young Adult     Reggae            575.733333
# 39  Young Adult       Rock            577.383333

# %%
#Find the mean of the songs repeated among each Subscription 
project.groupby('Subscription Type')['Repeat Song Rate (%)'].mean()
# Out:
# Subscription Type
# Free       42.773141
# Premium    42.016845
# Name: Repeat Song Rate (%), dtype: float64

# %%
project.describe()
# Out:
#                Age  Minutes Streamed Per Day  Number of Songs Liked  \
# count  5000.000000               5000.000000             5000.00000
# mean     36.664000                309.237200              253.51720
# std      13.763844                172.029822              146.36928
# min      13.000000                 10.000000                1.00000
# 25%      25.000000                161.000000              126.00000
# 50%      37.000000                316.000000              254.00000
# 75%      49.000000                457.250000              382.00000
# max      60.000000                600.000000              500.00000
#
#        Discover Weekly Engagement (%)  Repeat Song Rate (%)  \
# count                     5000.000000           5000.000000
# mean                        50.296464             42.391060
# std                         23.171936             21.444121
# min                         10.020000              5.000000
# 25%                         30.147500             24.195000
# 50%                         50.420000             41.960000
# 75%                         70.337500             60.740000
# max                         89.990000             79.990000
#
#        Daily Hours Streamed
# count           5000.000000
# mean               5.153953
# std                2.867164
# min                0.166667
# 25%                2.683333
# 50%                5.266667
# 75%                7.620833
# max               10.000000

# %%
#Extraxt the complete data of Australia 
Australia=project[project['Country']=='Australia']
Australia
# Out:
#      User_ID  Age    Country Streaming Platform  Top Genre  \
# 3      U1003   55  Australia            YouTube     Reggae
# 6      U1006   49  Australia              Tidal    Country
# 20     U1020   33  Australia        Apple Music        EDM
# 49     U1049   35  Australia        Apple Music        EDM
# 62     U1062   35  Australia            Spotify       Jazz
# ...      ...  ...        ...                ...        ...
# 4975   U5975   16  Australia        Apple Music  Classical
# 4979   U5979   24  Australia        Apple Music    Hip-Hop
# 4980   U5980   38  Australia        Apple Music       Jazz
# 4994   U5994   55  Australia       Amazon Music  Classical
# 4996   U5996   38  Australia             Deezer    Hip-Hop
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 3                          348                    349           Dua Lipa
# 6                          547                     70      Billie Eilish
# 20                          58                    417        Post Malone
# 49                         249                    178           Dua Lipa
# 62                         372                    283         Ed Sheeran
# ...                        ...                    ...                ...
# 4975                       513                    335           Dua Lipa
# 4979                       579                    346         Ed Sheeran
# 4980                       350                    409         Ed Sheeran
# 4994                       222                    444           Dua Lipa
# 4996                       225                    218                BTS
#
#      Subscription Type Listening Time (Morning/Afternoon/Night)  \
# 3              Premium                                  Morning
# 6                 Free                                    Night
# 20             Premium                                Afternoon
# 49                Free                                Afternoon
# 62                Free                                  Morning
# ...                ...                                      ...
# 4975              Free                                    Night
# 4979              Free                                    Night
# 4980           Premium                                  Morning
# 4994           Premium                                    Night
# 4996           Premium                                    Night
#
#       Discover Weekly Engagement (%)  Repeat Song Rate (%)  \
# 3                              31.27                 76.51
# 6                              11.92                 37.75
# 20                             87.41                 44.49
# 49                             34.56                 19.68
# 62                             84.71                 56.46
# ...                              ...                   ...
# 4975                           77.72                  7.49
# 4979                           35.43                 41.20
# 4980                           68.65                 52.32
# 4994                           56.49                 44.17
# 4996                           17.08                 58.23
#
#       Daily Hours Streamed    Age_Group
# 3                 5.800000        Adult
# 6                 9.116667        Adult
# 20                0.966667        Adult
# 49                4.150000        Adult
# 62                6.200000        Adult
# ...                    ...          ...
# 4975              8.550000         Teen
# 4979              9.650000  Young Adult
# 4980              5.833333        Adult
# 4994              3.700000        Adult
# 4996              3.750000        Adult
#
# [526 rows x 14 columns]

# %%
#Find mean of repeat song rate among each streamiong paltform 
project.groupby('Streaming Platform')['Repeat Song Rate (%)'].mean().sort_values(ascending=False)
# Out:
# Streaming Platform
# Amazon Music    43.163031
# Spotify         42.961814
# Deezer          42.827014
# YouTube         42.423090
# Tidal           42.004976
# Apple Music     40.880025
# Name: Repeat Song Rate (%), dtype: float64

# %%
#Find the sum of hours streamed in Australia and store it in to a new variabel name genre 
top_genre_australia=Australia.groupby('Top Genre')
genre=top_genre_australia['Daily Hours Streamed'].sum().sort_values(ascending=False)
genre  =  dict(genre)
genre
# Out:
# {'Rock': 329.55,
#  'Pop': 313.21666666666664,
#  'Jazz': 310.8833333333333,
#  'Reggae': 302.73333333333335,
#  'Hip-Hop': 292.3,
#  'R&B': 282.0833333333333,
#  'EDM': 277.5,
#  'Country': 227.63333333333333,
#  'Classical': 213.85,
#  'Metal': 210.68333333333334}

# %%
project.groupby('Country')['Discover Weekly Engagement (%)'].mean()
# Out:
# Country
# Australia      51.454354
# Brazil         49.774724
# Canada         49.292150
# France         50.270304
# Germany        50.639490
# India          51.432020
# Japan          50.433646
# South Korea    50.300678
# UK             48.579516
# USA            50.870124
# Name: Discover Weekly Engagement (%), dtype: float64

# %%
Australia['Subscription Type'].value_counts()
# Out:
# Subscription Type
# Free       268
# Premium    258
# Name: count, dtype: int64

# %%
project.groupby("Country")["Streaming Platform"].value_counts(normalize=True).unstack() * 100
# Out:
# Streaming Platform  Amazon Music  Apple Music     Deezer    Spotify  \
# Country
# Australia              15.969582    17.490494  15.019011  15.779468
# Brazil                 17.913386    14.763780  16.929134  15.354331
# Canada                 16.173570    15.581854  16.370809  16.173570
# France                 14.807302    15.415822  18.052738  16.024341
# Germany                17.197452    15.711253  17.409766  15.498938
# India                  15.918367    13.877551  22.448980  17.142857
# Japan                  17.311609    19.348269  15.071283  16.904277
# South Korea            17.054264    12.403101  15.697674  20.155039
# UK                     20.542636    16.666667  15.310078  15.116279
# USA                    19.294606    18.049793  16.804979  17.219917
#
# Streaming Platform      Tidal    YouTube
# Country
# Australia           21.482890  14.258555
# Brazil              17.125984  17.913386
# Canada              16.568047  19.132150
# France              19.066937  16.632860
# Germany             17.409766  16.772824
# India               15.102041  15.510204
# Japan               13.849287  17.515275
# South Korea         18.217054  16.472868
# UK                  16.085271  16.279070
# USA                 14.730290  13.900415

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Bar Chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns
genres = list(genre.keys())
values = [round(value, 2) for value in genre.values()]
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=genres, y=values,hue=genres ,palette="coolwarm",legend=False, edgecolor="black")
plt.xlabel("Music Genre", fontsize=14, fontweight='bold')
plt.ylabel("Popularity Score", fontsize=14, fontweight='bold')
plt.title("Top Music Genres by number of Hours Streamed in Australia", fontsize=16, fontweight='bold', pad=20)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
for p in ax.patches:
    ax.annotate(f'{p.get_height():,}', 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
count=project.groupby('Top Genre')['Daily Hours Streamed'].sum()
count=dict(count)
count
# Out:
# {'Classical': 2482.85,
#  'Country': 2369.5666666666666,
#  'EDM': 2730.766666666667,
#  'Hip-Hop': 2517.4333333333334,
#  'Jazz': 2739.0333333333333,
#  'Metal': 2470.5333333333333,
#  'Pop': 2349.8166666666666,
#  'R&B': 2599.15,
#  'Reggae': 2721.1666666666665,
#  'Rock': 2789.45}

# %%
genres = list(count.keys())
values = [round(value, 2) for value in count.values()]
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=genres, y=values,hue=genres ,palette="coolwarm",legend=False, edgecolor="black")
plt.xlabel("Genres", fontsize=14, fontweight='bold')
plt.ylabel("Number of Hourly Streamed", fontsize=14, fontweight='bold')
plt.title("Top 10 Most Popular Genres Globallay", fontsize=16, fontweight='bold', pad=20)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
for p in ax.patches:
    ax.annotate(f'{p.get_height():,}', 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
y=project.groupby('Streaming Platform')['Number of Songs Liked'].sum()
y
# Out:
# Streaming Platform
# Amazon Music    225478
# Apple Music     201865
# Deezer          213683
# Spotify         204284
# Tidal           213346
# YouTube         208930
# Name: Number of Songs Liked, dtype: int64

# %%
mycolors=['Red','Green','Blue','Yellow','Magenta','AntiqueWhite']
plt.pie(y.values,labels=y.index,colors=mycolors,startangle=90,autopct='%0.2f%%')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
fig= plt.figure(figsize=(12,6))
ax=fig.gca()
project[['Minutes Streamed Per Day','Age_Group']].boxplot(by = 'Age_Group', ax = ax)
ax.set_title('Per day minutes streamed by Different Age Groups',fontsize=20,fontweight='bold')
ax.set_xlabel('Age Groups',fontsize=14,fontweight='bold')
ax.set_ylabel('Minutes streamed',fontsize=14,fontweight='bold')
plt.show()

# %% [markdown]
# ## Corelation

# %%
project1=project[['Age','Minutes Streamed Per Day','Number of Songs Liked','Discover Weekly Engagement (%)','Repeat Song Rate (%)']]
corelation=project1.corr()
corelation
# Out:
#                                      Age  Minutes Streamed Per Day  \
# Age                             1.000000                  0.004166
# Minutes Streamed Per Day        0.004166                  1.000000
# Number of Songs Liked          -0.016668                  0.023487
# Discover Weekly Engagement (%) -0.008872                 -0.004280
# Repeat Song Rate (%)            0.007626                 -0.037508
#
#                                 Number of Songs Liked  \
# Age                                         -0.016668
# Minutes Streamed Per Day                     0.023487
# Number of Songs Liked                        1.000000
# Discover Weekly Engagement (%)               0.012447
# Repeat Song Rate (%)                         0.005942
#
#                                 Discover Weekly Engagement (%)  \
# Age                                                  -0.008872
# Minutes Streamed Per Day                             -0.004280
# Number of Songs Liked                                 0.012447
# Discover Weekly Engagement (%)                        1.000000
# Repeat Song Rate (%)                                  0.004186
#
#                                 Repeat Song Rate (%)
# Age                                         0.007626
# Minutes Streamed Per Day                   -0.037508
# Number of Songs Liked                       0.005942
# Discover Weekly Engagement (%)              0.004186
# Repeat Song Rate (%)                        1.000000

# %% [markdown]
# ## Heat Map

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corelation,cbar=True,square=True,fmt='.2f',annot=True, annot_kws={'size':8},cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Line Chart

# %%
avg_minutes_by_age = project.groupby('Age')['Minutes Streamed Per Day'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=avg_minutes_by_age, x='Age', y='Minutes Streamed Per Day')
plt.title('Average Minutes Streamed Per Day by Age ')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Country', hue='Subscription Type')
plt.title('Subscription Type by Country')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
